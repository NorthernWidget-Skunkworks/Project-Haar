# %%
import pandas as pd
data = pd.read_csv('Data.csv', skiprows = 2, encoding='ISO-8859-1') #Read in data from CSV
data.columns = ["Time","TempA","PresA","RHA","TempB","PresB","RHB"]
data["Time"] = data["Time"]/1000 #Convert to seconds
print(data)
# Out:
#          Time    TempA   PresA    RHA    TempB   PresB    RHB
# 0        6.92  25.4513  970.51  46.16  24.5354  968.93  47.19
# 1        7.92  25.4513  970.51  46.19  24.5354  968.95  47.15
# 2        8.92  25.4646  970.53  46.18  24.5354  968.93  47.15
# 3        9.92  25.4780  970.52  46.17  24.5087  968.94  47.19
# 4       10.92  25.4646  970.51  46.16  24.5514  968.93  47.17
# ...       ...      ...     ...    ...      ...     ...    ...
# 5362  5368.92  25.0267  971.26  48.22  25.0053  969.73  48.17
# 5363  5369.92  25.0694  971.26  48.20  24.9760  969.73  48.14
# 5364  5370.92  25.0694  971.25  48.15  25.0053  969.77  48.15
# 5365  5371.92  25.0855  971.25  48.19  24.9760  969.75  48.19
# 5366  5372.92  25.0988  971.26  48.14  24.9760  969.75  48.16
#
# [5367 rows x 7 columns]

# %%
ax = data.plot(kind = 'line', x = 'Time', y = ['RHA','RHB'], title='Humidity Response Time')
ax.set_ylabel("Relative Humidity [%]")
ax.get_figure().savefig('HumidityResponse.pdf')
ax.get_figure().savefig('HumidityResponse.png')

# %%
from array import array
maxVal = max(data['RHA'])
error = array("f", abs(data['RHA'] - maxVal))


tau = data['Time'][error.index(min(error))]
print((tau)/60) #Print tau result in minutes
# Out:
# 53.815333333333335
