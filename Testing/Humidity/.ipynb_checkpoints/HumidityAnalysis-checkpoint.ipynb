# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
data = pd.read_csv('Data.csv', skiprows = 2, encoding='ISO-8859-1') #Read in data from CSV
# data.columns = ["Time","TempA","PresA","RHA","TempB","PresB","RHB"]
data.columns = ["Time","TempCtrl","RHCtrl","PresA","TempA","RHA","PresB","TempB","RHB"]
data["Time"] = data["Time"] #Convert to seconds
print(data)
# Out:
#       Time  TempCtrl  RHCtrl   PresA  TempA    RHA   PresB  TempB    RHB
# 0       14     22.07   45.10  969.48  22.09  48.11  970.92  22.18  50.05
# 1       17     22.05   45.10  969.50  22.20  48.18  970.92  22.20  50.02
# 2       20     22.04   45.16  969.53  22.23  48.19  970.97  22.20  50.02
# 3       23     22.05   45.15  969.50  22.16  48.13  970.91  22.17  50.01
# 4       26     22.04   45.11  969.52  22.13  48.07  970.95  22.20  50.04
# ...    ...       ...     ...     ...    ...    ...     ...    ...    ...
# 3266  9821     22.08   60.21  970.97  22.19  62.74  972.42  22.20  60.62
# 3267  9824     22.05   60.18  970.99  22.23  62.76  972.42  22.20  60.63
# 3268  9827     22.05   60.18  971.00  22.20  62.69  972.41  22.22  60.67
# 3269  9830     22.05   60.21  971.01  22.26  62.78  972.43  22.21  60.62
# 3270  9833     22.07   60.21  971.02  22.16  62.78  972.44  22.24  60.63
#
# [3271 rows x 9 columns]

# %%
style.use('default')
styles = ['-','--',':']
data.plot(kind = 'line', x = 'Time', y = ['RHCtrl','RHA','RHB'], style=styles, title='Humidity Response Time',figsize=(7.5,3.5),xlim=(2000,10000), grid=True)
plt.ylabel("Relative Humidity [%]")
plt.xlabel("Time [s]")
plt.legend(["Control", "Open","Closed"], loc='lower right')
plt.tight_layout()
plt.savefig('HumidityResponse.pdf', bbox_inches="tight")
plt.savefig('HumidityResponse.png',format='png',dpi=300)
