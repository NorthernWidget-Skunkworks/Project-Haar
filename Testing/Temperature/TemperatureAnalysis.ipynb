# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
data = pd.read_csv('Data.csv', skiprows = 1, encoding='ISO-8859-1') #Read in data from CSV
data.columns = ["Time","TempCtrl","RHCtrl","PresA","TempA","RHA","PresB","TempB","RHB"]
# data["Time"] = data["Time"]/1000 #Convert to seconds
print(data)
# Out:
#         Time  TempCtrl  RHCtrl   PresA  TempA    RHA   PresB   TempB    RHB
# 0          8    15.870   60.83  979.00  16.09  61.99  980.56  18.765  60.44
# 1          9    15.870   60.82  979.00  16.10  61.99  980.60  18.760  60.38
# 2         11    15.870   60.81  979.00  16.11  61.99  980.59  18.765  60.36
# 3         13    15.875   60.82  979.00  16.11  62.00  980.58  18.770  60.35
# 4         14    15.880   60.82  979.00  16.11  62.01  980.59  18.755  60.28
# ...      ...       ...     ...     ...    ...    ...     ...     ...    ...
# 15587  27070    24.970   31.83  977.12  25.17  33.73  978.87  25.050  37.23
# 15588  27073    24.970   31.83  977.12  25.17  33.73  978.85  25.050  37.20
# 15589  27076    24.970   31.83  977.12  25.17  33.73  978.86  25.040  37.20
# 15590  27079    24.970   31.83  977.12  25.17  33.73  978.86  25.050  37.21
# 15591  27082    24.970   31.83  977.12  25.17  33.73  978.83  25.050  37.20
#
# [15592 rows x 9 columns]

# %%
style.use('default')
styles = ['-','--',':']
data.plot(kind = 'line', x = 'Time', y = ['TempCtrl','TempA','TempB'], style=styles, title='Temperature Response Time',xlim=(1000,5000),figsize=(7.5,3.5), grid=True)
plt.ylabel("Temperature [°C]")
plt.xlabel("Time [s]")
plt.legend(["Control", "Open","Closed"], loc='lower right')
plt.tight_layout()
plt.savefig('TempResponse.pdf', bbox_inches="tight")
plt.savefig('TempResponse.png',format='png', dpi=300)
